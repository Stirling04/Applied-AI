// %%
Part C - Describe the input required for your implementation: graph, time series, etc. Where will you get the data? Does the data need to be prepared in specific format? Describe the format of the input data [4] and any pre-processing require.

Input required for implementation:

Input type: Tabular numeric dataset(Regression):
  . feature Names: Age, Sex, BMI, bp, s1, s2, s3, s4, s5, s6
  . Reason: Neural Networks require numeric input for scaling and computation. 


Data Source:
Source: sklearn load_diabetes dataset.

format procided by sklearn:
  . x: Numpy array shape - (442, 10).
  . y: Numpy array shape - (442).

Required Data format:
Tabular Numeric format - Each column/feature is a patient.
Columns include:
  . Age, Sex, BMI, bp, s1, s2, s3, s4, s5, s6
  . Target column - Target, which represents diabetes progression.


Preprocessing Process:
Inspect data & handle missing values:
  . Check for a missing value or values.
Outlier detection and removal:
  .  detect using interquartile range and then remove extreme outliers.
Correlation analysis:
  . Explore relationships between features and target variable.
Feature Scaling:
  . Standardization - which will help ensure neaural network convergence.
  . Optimal normalization.
Train & Test the neaural network model:
  . Split data into 80% training and 20% subsets which will be used to help evaluate the performance of the model.
